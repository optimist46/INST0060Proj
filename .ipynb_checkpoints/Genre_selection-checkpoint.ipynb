# %%
import pandas as pd
import seaborn as sns

# %%
find_dataset = 'Data/New1_noQuestion Mark.csv'
dataset = pd.read_csv(find_dataset)
dataset = dataset.iloc[:, :-1]

# %%
dataset = dataset.corr()
sns.heatmap(dataset)
# Out:
# <AxesSubplot: >

# %%
track_genre
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /var/folders/f9/88_2t8j106d11pk5vg4h3q_h0000gn/T/ipykernel_9938/2093620954.py in <module>
# ----> 1 track_genre
#
# NameError: name 'track_genre' is not defined
