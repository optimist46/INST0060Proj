# %%
import pandas as pd
import seaborn as sns

# %%
find_dataset = 'Data/Processed_full_data.csv'
dataset = pd.read_csv(find_dataset)
dataset = dataset.iloc[:, :-1]

# %%
dataset = dataset.corr()
sns.heatmap(dataset)
# Out:
# <AxesSubplot: >

# %%
track_genre
