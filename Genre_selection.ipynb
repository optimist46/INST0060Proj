# %%
import pandas as pd
import seaborn as sns

# %%
find_dataset = 'Data/New1_noQuestionMark.csv'
dataset = pd.read_csv(find_dataset)
dataset = dataset.iloc[:, -1:]

# %%
dataset.groupby(dataset.columns.tolist(),as_index=False).size()
# Out:
#   track_genre  size
# 0   Classical  4500
# 1     Country  4486
# 2     Hip-Hop  4520
# 3        Jazz  4521
# 4        Rock  4561

# %%
datasetcorr = dataset.corr(numeric_only=False)
sns.heatmap(datasetcorr)
# Out:
# <AxesSubplot: >

# %%
dataset
# Out:
#        popularity  acousticness  danceability  duration_ms  energy  \
# 0              44       0.00621         0.711       285987  0.6210
# 1              34       0.34700         0.729       103703  0.5150
# 2              39       0.91800         0.484       228733  0.0693
# 3              36       0.03450         0.473       342867  0.8230
# 4              53       0.50100         0.921       151733  0.2660
# ...           ...           ...           ...          ...     ...
# 22583          59       0.03340         0.913           -1  0.5740
# 22584          72       0.15700         0.709       251860  0.3620
# 22585          51       0.00597         0.693       189483  0.7630
# 22586          65       0.08310         0.782       262773  0.4720
# 22587          67       0.10200         0.862       267267  0.6420
#
#        instrumentalness  key  liveness  loudness  mode  speechiness    tempo  \
# 0              0.029700   11     0.159    -7.429     1       0.0382  142.065
# ...

# %%
datasetcorr
# Out:
#                   popularity  acousticness  danceability  duration_ms  \
# popularity          1.000000     -0.515677      0.416030    -0.134185
# acousticness       -0.515677      1.000000     -0.505405     0.134854
# danceability        0.416030     -0.505405      1.000000    -0.232562
# duration_ms        -0.134185      0.134854     -0.232562     1.000000
# energy              0.481790     -0.827509      0.458405    -0.136139
# instrumentalness   -0.445454      0.516330     -0.408443     0.179500
# key                -0.008883      0.005456     -0.011697    -0.007890
# liveness           -0.006151     -0.101796      0.001265    -0.001524
# loudness            0.530187     -0.762931      0.550040    -0.157567
# mode                0.001180      0.005756     -0.057601    -0.025394
# speechiness         0.192827     -0.203151      0.321546    -0.088371
# tempo               0.149839     -0.251067      0.074107    -0.061748
# ...
